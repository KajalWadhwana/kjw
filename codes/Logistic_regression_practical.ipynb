# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("/content/drive/MyDrive/logistic regression cancer/breast-cancer.csv", header = None)
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
x[6].value_counts()
x[6].replace("?",x[6].mode().iloc[0], inplace= True)
x[6].value_counts()
# Out:
# 1     418
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# 9       9
# 7       8
# 6       4
# Name: 6, dtype: int64

# %%
x=x.drop([0],axis=1)
x
# Out:
#      1   2   3  4  5   6   7   8  9
# 0    5   1   1  1  2   1   3   1  1
# 1    5   4   4  5  7  10   3   2  1
# 2    3   1   1  1  2   2   3   1  1
# 3    6   8   8  1  3   4   3   7  1
# 4    4   1   1  3  2   1   3   1  1
# ..  ..  ..  .. .. ..  ..  ..  .. ..
# 694  3   1   1  1  3   2   1   1  1
# 695  2   1   1  1  2   1   1   1  1
# 696  5  10  10  3  7   3   8  10  2
# 697  4   8   6  4  3   4  10   6  1
# 698  4   8   8  5  4   5  10   4  1
#
# [699 rows x 9 columns]

# %%
x.shape
# Out:
# (699, 9)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[91  1]
#  [ 2 46]]

# %% [markdown]
# # K-fold cross validation
#
# **its a technique where your model will by default generate 10 accuracies and then you can see the value of mean of all the accuracies and also the standard deviation**

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(classifier, x_train, y_train, cv = 10)
print("accuracy: {:.2f} %" .format(accuracies.mean()*100))
print("standard deviation: {:.2f} %" .format(accuracies.std()*100))
# Out:
# accuracy: 96.24 %
# standard deviation: 2.47 %
